# %%
#【案例3-1】Python程序代码示例
#Python程序代码示例
#3.1.2

# -*- coding: utf-8 -*-                     #源代码编码格式
"""
Created on Tue Feb 25 09:07:47 2020         #注释信息
@author: Administrator
"""
import datetime                            #引入外部模块
# 获取当前时间                              #注释信息
t=datetime.datetime.now()                   #源代码

def hi(name):                               #定义函数
    """                                      #注释及帮助信息，可以用__doc__获取字符串内容
     Parameters
    ----------
    f : list
        files and directories list
    Returns
    -------
    flpy : list
        list only contains python files.
    """
    return 'hello:'+ str(name)               #函数返回值

if __name__ == "__main__":                   #判断是否运行在主模块
    print(t)
    print(hi('James'))                       #程序源代码
# Out:
# 2020-11-08 15:27:00.745691
# hello:James

# %%
#【案例3-2】第一个注释。
#3.1.4 这是一行注释信息
print("上面这一行是注释")
# Out:
# 上面这一行是注释

# %%
#【案例3-3】查看__doc__属性。
#3.1.4 输出帮助信息
print(hi.__doc__)
# Out:
#                                       #注释及帮助信息，可以用__doc__获取字符串内容
#      Parameters
#     ----------
#     f : list
#         files and directories list
#     Returns
#     -------
#     flpy : list
#         list only contains python files.

# %%
#【案例3-3】查看__doc__属性。
#3.1.4 输出帮助信息
help(hi)
# Out:
# Help on function hi in module __main__:
#
# hi(name)
#     #注释及帮助信息，可以用__doc__获取字符串内容
#      Parameters
#     ----------
#     f : list
#         files and directories list
#     Returns
#     -------
#     flpy : list
#         list only contains python files.

# %%
#【案例3-4】Python语言代码块缩进代码示例。
#3.1.5 Python语言代码块缩进代码示例
if True:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#【案例3-4】Python语言代码块缩进代码示例。
#3.1.5 缩进错误示范
if True:
    print("Answer")
    print("True")
else:
    print("Answer")
  print("False")
# Out:
#   File "<tokenize>", line 7
#     print("False")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#【案例3-5】Python语言一行长代码换行写法代码示例。
#3.1.5 分行语句

total = "A33"\
        "B44"\
        "C55"
print(total)
# Out:
# A33B44C55

# %%
#【案例3-6】查看当前Python版本所有关键字。
#3.2 关键字分类

import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
#【案例3-7】查看名字空间。
#3.6 Python语言的名字空间
#变量定义前
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'exit',
#  'get_ipython',
#  'hi',
#  'keyword',
#  'quit',
#  't',
#  'total']

# %%
#【案例3-7】查看名字空间。
#3.6 Python语言的名字空间
#变量定义后
x = 100
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_17',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'exit',
#  'get_ipython',
#  'hi',
#  'keyword',
#  'quit',
#  't',
#  'total',
#  'x']

# %%
#【案例3-8】del()函数案例。
#3.6 Python语言的名字空间
#删除变量
del(x)
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_17',
#  '_18',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'exit',
#  'get_ipython',
#  'hi',
#  'keyword',
#  'quit',
#  't',
#  'total']

# %%
#【案例3-9】定义一个函数后的命名空间
#3.6 Python语言的名字空间
#定义函数
def s(length):
    x = 300
    y = 400
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_17',
#  '_18',
#  '_19',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'exit',
#  'get_ipython',
#  'hi',
#  'keyword',
#  'quit',
#  's',
#  't',
#  'total']

# %%
#【案例3-10】查看变量的使用情况。
#3.6 Python语言的名字空间
#查看全局变量
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020         #注释信息\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
# ...

# %%
#【案例3-10】查看变量的使用情况。
#3.6 Python语言的名字空间
#查看局部变量
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020         #注释信息\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
# ...

# %%
#【案例3-10】查看变量的使用情况。
#3.6 Python语言的名字空间
#查看局部变量
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': '\nCreated on Tue Feb 25 09:07:47 2020         #注释信息\n@author: Administrator\n',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# -*- coding: utf-8 -*-\n"""\nCreated on Tue Feb 25 09:07:47 2020\n@author: Administrator\n"""\nimport datetime\n# 获取当前时间\nt=datetime.datetime.now()\n\ndef hi(name):\n    """\n     Parameters\n    ----------\n    f : list\n        files and directories list\n    Returns\n    -------\n    flpy : list\n        list only contains python files.\n    """\n   return \'hello:\'+ str(name)\n\nif __name__ == "__main__":\n    print(t)\n    print(hi(\'James\'))\n   ',
# ...

# %%
#【案例3-11】NameError异常举例。
#3.6 Python语言的名字空间
#查看一个未定义的变量会报错
aa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-bf731c1564c0> in <module>
#       1 #3.6 Python语言的名字空间
#       2 #查看一个未定义的变量会报错
# ----> 3 aa
#
# NameError: name 'aa' is not defined

# %%
#【案例3-12】导入模块。
#3.7 Python的模块
import random
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'datetime',
#  'exit',
#  'get_ipython',
#  'hi',
#  'keyword',
#  'quit',
#  'random',
#  's',
#  't',
#  'total']

# %%
#【案例3-13】查看random名字空间。
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_BuiltinMethodType',
#  '_MethodType',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_inst',
#  '_itertools',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
#【案例3-14】调用模块内函数案例。
#3.7 Python的模块
print(random.randint(1,100))
# Out:
# 4

# %%
#【案例3-15】第二种导入方式调用函数案例。
#3.7 Python的模块
#导入模块导入到全局空间内
from random import *
dir()
# Out:
# ['In',
#  'Out',
#  'Random',
#  'SystemRandom',
#  '_',
#  '_17',
#  '_18',
#  '_19',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_26',
#  '_27',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'betavariate',
#  'choice',
#  'choices',
#  'datetime',
#  'exit',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'get_ipython',
#  'getrandbits',
#  'getstate',
#  'hi',
#  'keyword',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'quit',
#  'randint',
#  'random',
#  'randrange',
#  's',
#  'sample',
#  'seed',
# ...

# %%
#【案例3-15】第二种导入方式调用函数案例。
#3.7 Python的模块
#导入模块导入到全局空间后，调用相关的函数
print(randint(1,100))
# Out:
# 84
